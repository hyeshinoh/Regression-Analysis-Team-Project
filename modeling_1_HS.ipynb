# %% [markdown]
# #### **Regression-Analysis-Team-Project** by Team 1

# %% [markdown]
# ##### Importing necessary libraries

# %%
####### what's in startup file #######
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import sklearn as sk

import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
# import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D

import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_color_codes()

# %%
####### what's not in startup file #######
from scipy import stats

# visualization in jupyter
# %matplotlib inline   

# ignore warning messeges
import warnings
warnings.filterwarnings('ignore')

import time

# %% [markdown]
# ##### Importing data
# - Properties Data

# %%
prop16 = pd.read_csv('data/properties_2016.csv')
prop17 = pd.read_csv('data/properties_2017.csv')

# %% [markdown]
# - Train Data

# %%
train16 = pd.read_csv('data/train_2016_v2.csv', parse_dates=["transactiondate"])
train17 = pd.read_csv('data/train_2017.csv', parse_dates=["transactiondate"])

# %% [markdown]
# - Submission Sample

# %%
submission_form = pd.read_csv('data/sample_submission.csv')

# %%
# traing16을 기준으로 prop16을 merge
merged16 = pd.merge(train16, prop16, on="parcelid", how="left")

# %%
# traing17을 기준으로 prop17을 merge
merged17 = pd.merge(train17, prop17, on="parcelid", how="left")

# %%
merged = pd.concat([merged16, merged17]).reset_index(drop=True)
merged.tail()
# Out:
#         parcelid  logerror transactiondate  airconditioningtypeid  \
# 167883  10833991 -0.002245      2017-09-20                    1.0
# 167884  11000655  0.020615      2017-09-20                    NaN
# 167885  17239384  0.013209      2017-09-21                    NaN
# 167886  12773139  0.037129      2017-09-21                    1.0
# 167887  12826780  0.007204      2017-09-25                    NaN
#
#         architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 167883                       NaN           NaN          3.0         3.0
# 167884                       NaN           NaN          2.0         2.0
# 167885                       NaN           NaN          2.0         4.0
# 167886                       NaN           NaN          1.0         3.0
# 167887                       NaN           NaN          2.0         3.0
#
#         buildingclasstypeid  buildingqualitytypeid         ...           \
# 167883                  NaN                    8.0         ...
# 167884                  NaN                    6.0         ...
# 167885                  NaN                    NaN         ...
# 167886                  NaN                    4.0         ...
# 167887                  NaN                    6.0         ...
#
#         numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 167883              NaN            NaN                    265000.0
# 167884              NaN            NaN                     70917.0
# 167885              1.0            NaN                     50683.0
# 167886              NaN            NaN                     32797.0
# 167887              NaN            NaN                    140000.0
#
#         taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 167883           379000.0          2016.0               114000.0    4685.34
# 167884           354621.0          2016.0               283704.0    4478.43
# 167885            67205.0          2016.0                16522.0    1107.48
# 167886            49546.0          2016.0                16749.0     876.43
# 167887           522000.0          2016.0               382000.0    6317.15
#
#         taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 167883                 NaN                 NaN         6.037132e+13
# 167884                 NaN                 NaN         6.037101e+13
# 167885                 NaN                 NaN         6.111008e+13
# 167886                 NaN                 NaN         6.037434e+13
# 167887                 NaN                 NaN         6.037503e+13
#
# [5 rows x 60 columns]

# %%
merged_des = merged.describe(include='all').transpose()
merged_des["missing_ratio"] = 1-(merged_des["count"]/merged.shape[0])
merged_des["dtype"] = merged.dtypes
merged_des.reset_index().tail()
# Out:
#                     index   count unique  top  freq first last         mean  \
# 55  landtaxvaluedollarcnt  167851    NaN  NaN   NaN   NaN  NaN       288880
# 56              taxamount  167843    NaN  NaN   NaN   NaN  NaN      5989.52
# 57     taxdelinquencyflag    4683      1    Y  4683   NaN  NaN          NaN
# 58     taxdelinquencyyear    4683    NaN  NaN   NaN   NaN  NaN      13.8272
# 59    censustractandblock  167002    NaN  NaN   NaN   NaN  NaN  6.04939e+13
#
#             std         min          25%         50%          75%  \
# 55       445645          22        83730      197776       355334
# 56      7214.73       19.92      2798.07     4501.04      6914.16
# 57          NaN         NaN          NaN         NaN          NaN
# 58      2.42166           3           13          14           15
# 59  1.05414e+12  6.0371e+13  6.03731e+13  6.0376e+13  6.05904e+13
#
#             max missing_ratio    dtype
# 55  4.89522e+07   0.000220385  float64
# 56       586639   0.000268036  float64
# 57          NaN      0.972106   object
# 58           99      0.972106  float64
# 59   4.8303e+14    0.00527733  float64

# %% [markdown]
# ##### Data의 format 등에 먼저 전처리를 해줄 수 있는 부분

# %%
# transaction date을 year와 month로 분리해 줌
merged['transaction_year'] = merged['transactiondate'].dt.year
merged['transaction_month'] = merged['transactiondate'].dt.month

# taxdelinquency는 "Y"를 True로 바꾸어 줌 (다른 dummy 변수들은 1이나 True로 되어 있음)
merged['taxdelinquencyflag'] = merged['taxdelinquencyflag'].replace('Y',True)
merged['taxdelinquencyflag'] = merged['taxdelinquencyflag'].fillna(False)

# taxdelinquencyyear는 4자리의 년도로 format을 맞춰줌
merged["taxdelinquencyyear"] = merged["taxdelinquencyyear"].apply(lambda x: x + 2000 if x <= 17 else x + 1900)

# 위도 경도를 원래 단위로 맞춰줌
merged["latitude"] = merged["latitude"]/1000000
merged["longitude"] = merged["longitude"]/1000000

# %% [markdown]
# ##### categorical / numerical variable 구분하기

# %%
vars = merged_des.reset_index()["index"].tolist()

cat_vars = ['transactiondate', 'transaction_year', 'transaction_month',
            'rawcensustractandblock', 'censustractandblock', 'fips',
            'regionidcity', 'regionidcounty', 'regionidneighborhood', 'regionidzip', 
            'architecturalstyletypeid', 'decktypeid', 'buildingclasstypeid', 'storytypeid',
            'typeconstructiontypeid', 'propertycountylandusecode', 'propertylandusetypeid',
            'propertyzoningdesc', 'taxdelinquencyflag', 'taxdelinquencyyear', 'assessmentyear',
            'heatingorsystemtypeid', 'airconditioningtypeid', 'hashottuborspa', 'fireplaceflag',
            'pooltypeid10', 'pooltypeid2', 'pooltypeid7']

num_vars = [i for i in vars if i not in cat_vars]

num_vars.remove('parcelid')
num_vars.remove('logerror')

print("number of categorical variables:", len(cat_vars))
print("number of numerical variables:", len(num_vars))
# Out:
# number of categorical variables: 28
# number of numerical variables: 32

# %% [markdown]
# ##### 카테고리 변수 중 float type이 많음 → 필요할 경우 str으로 바꿔주기
# - str: 'architecturalstyletypeid', 'rawcensustractandblock', 'censustractandblock', 'regionidcounty', 'fips', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'decktypeid', 'buildingclasstypeid', 'storytypeid', 'typeconstructiontypeid', 'propertylandusetypeid', 'heatingorsystemtypeid', 'airconditioningtypeid'
#     - 일단 년도 변수는 계산 등의 조작 가능성을 고려해 바꿔주지 않음: 'assessmentyear', 'taxdelinquencyyear'
# - boolean: 'fireplaceflag', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'hashottuborspa'

# %%
def cat_to_str(column_name):
    merged[column_name] = merged[column_name].astype("str")
    merged[column_name][merged[column_name] == 'nan'] = np.nan

# %%
ls_c_to_s = ['architecturalstyletypeid', 'rawcensustractandblock', 'censustractandblock',
             'regionidcounty', 'fips', 'regionidcity', 'regionidcounty', 'regionidneighborhood',
             'decktypeid', 'buildingclasstypeid', 'storytypeid', 'typeconstructiontypeid',
             'propertylandusetypeid', 'heatingorsystemtypeid', 'airconditioningtypeid']

for var in ls_c_to_s:
    cat_to_str(var)

# %%
# dummy 변수를 True/False로 인코딩
def cat_to_bln(column_name):
    merged[column_name] = merged[column_name].replace(1,True)
    merged[column_name] = merged[column_name].fillna(False)

# %%
c_to_b = ['fireplaceflag', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'hashottuborspa']

for var in c_to_b:
    cat_to_bln(var)

# %%
merged_des = merged.describe(include='all').transpose()
merged_des["missing_ratio"] = 1-(merged_des["count"]/merged.shape[0])
merged_des["dtype"] = merged.dtypes
merged_des
# Out:
#                                count unique                  top    freq  \
# parcelid                      167888    NaN                  NaN     NaN
# logerror                      167888    NaN                  NaN     NaN
# transactiondate               167888    616  2017-06-30 00:00:00    1195
# airconditioningtypeid          53788      6                  1.0   49854
# architecturalstyletypeid         468      6                  7.0     394
# basementsqft                      93    NaN                  NaN     NaN
# bathroomcnt                   167854    NaN                  NaN     NaN
# bedroomcnt                    167854    NaN                  NaN     NaN
# buildingclasstypeid               31      2                  4.0      30
# buildingqualitytypeid         107173    NaN                  NaN     NaN
# calculatedbathnbr             166056    NaN                  NaN     NaN
# decktypeid                      1272      1                 66.0    1272
# finishedfloor1squarefeet       12893    NaN                  NaN     NaN
# calculatedfinishedsquarefeet  166992    NaN                  NaN     NaN
# finishedsquarefeet12          159519    NaN                  NaN     NaN
# finishedsquarefeet13              75    NaN                  NaN     NaN
# finishedsquarefeet15            6591    NaN                  NaN     NaN
# finishedsquarefeet50           12893    NaN                  NaN     NaN
# finishedsquarefeet6              807    NaN                  NaN     NaN
# fips                          167854      3               6037.0  109270
# fireplacecnt                   17896    NaN                  NaN     NaN
# fullbathcnt                   166056    NaN                  NaN     NaN
# garagecarcnt                   55457    NaN                  NaN     NaN
# garagetotalsqft                55457    NaN                  NaN     NaN
# hashottuborspa                167888      2                False  163984
# heatingorsystemtypeid         105651     12                  2.0   71936
# latitude                      167854    NaN                  NaN     NaN
# longitude                     167854    NaN                  NaN     NaN
# lotsizesquarefeet             149446    NaN                  NaN     NaN
# poolcnt                        34075    NaN                  NaN     NaN
# ...                              ...    ...                  ...     ...
# pooltypeid2                   167888      2                False  165610
# pooltypeid7                   167888      2                False  136112
# propertycountylandusecode     167853     90                 0100   57628
# propertylandusetypeid         167854     14                261.0  113078
# propertyzoningdesc            108789   2346                 LAR1   14444
# rawcensustractandblock        167854  57811   60379203.391054004     142
# regionidcity                  164579    178              12447.0   38562
# regionidcounty                167854      3               3101.0  109270
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt                    NaN                  NaN
# taxvaluedollarcnt                             NaN                  NaN
# assessmentyear                                NaN                  NaN
# landtaxvaluedollarcnt                         NaN                  NaN
# taxamount                                     NaN                  NaN
# taxdelinquencyflag                            NaN                  NaN
# taxdelinquencyyear                            NaN                  NaN
# censustractandblock                           NaN                  NaN
# transaction_year                              NaN                  NaN
# transaction_month                             NaN                  NaN
#
#                                      mean          std          min  \
# parcelid                      1.29954e+07  3.01607e+06  1.07117e+07
# logerror                        0.0139063     0.165706     -4.65542
# transactiondate                       NaN          NaN          NaN
# airconditioningtypeid                 NaN          NaN          NaN
# architecturalstyletypeid              NaN          NaN          NaN
# basementsqft                      695.376      583.952           38
# bathroomcnt                       2.28827      1.00084            0
# bedroomcnt                        3.04174      1.14913            0
# buildingclasstypeid                   NaN          NaN          NaN
# buildingqualitytypeid             6.01546       1.8828            1
# calculatedbathnbr                 2.31254     0.977808            1
# decktypeid                            NaN          NaN          NaN
# finishedfloor1squarefeet          1356.49      661.069           44
# calculatedfinishedsquarefeet      1778.63      940.356            2
# finishedsquarefeet12              1752.33      921.361            2
# finishedsquarefeet13              1395.71      116.539         1056
# finishedsquarefeet15              2368.33       1124.3          560
# finishedsquarefeet50              1367.65      698.669           44
# finishedsquarefeet6               2197.29      1300.55          257
# fips                                  NaN          NaN          NaN
# fireplacecnt                      1.18943     0.487327            1
# fullbathcnt                       2.24534     0.964703            1
# garagecarcnt                      1.81351     0.599447            0
# garagetotalsqft                   347.604      264.566            0
# hashottuborspa                        NaN          NaN          NaN
# heatingorsystemtypeid                 NaN          NaN          NaN
# latitude                          34.0068     0.265118      33.3393
# longitude                        -118.201     0.360059     -119.475
# lotsizesquarefeet                 29510.6       122459          167
# poolcnt                                 1            0            1
# ...                                   ...          ...          ...
# pooltypeid2                           NaN          NaN          NaN
# pooltypeid7                           NaN          NaN          NaN
# propertycountylandusecode             NaN          NaN          NaN
# propertylandusetypeid                 NaN          NaN          NaN
# propertyzoningdesc                    NaN          NaN          NaN
# rawcensustractandblock                NaN          NaN          NaN
# regionidcity                          NaN          NaN          NaN
# regionidcounty                        NaN          NaN          NaN
# regionidneighborhood                  NaN          NaN          NaN
# regionidzip                       96586.4      3723.01        95982
# roomcnt                           1.47748       2.8215            0
# storytypeid                           NaN          NaN          NaN
# threequarterbathnbr               1.00913     0.109294            1
# typeconstructiontypeid                NaN          NaN          NaN
# unitcnt                           1.11037     0.988168            1
# yardbuildingsqft17                307.919      227.431           11
# yardbuildingsqft26                271.261      293.611           12
# yearbuilt                         1968.57      23.7772         1824
# numberofstories                   1.43776     0.544508            1
# fireplaceflag                         NaN          NaN          NaN
# structuretaxvaluedollarcnt         184346       219284           44
# taxvaluedollarcnt                  472683       602837           22
# assessmentyear                    2015.46     0.498569         2015
# landtaxvaluedollarcnt              288880       445645           22
# taxamount                         5989.52      7214.73        19.92
# taxdelinquencyflag                    NaN          NaN          NaN
# taxdelinquencyyear                2013.78      1.69046         1999
# censustractandblock                   NaN          NaN          NaN
# transaction_year                  2016.46     0.498577         2016
# transaction_month                 5.48544      2.64165            1
#
#                                      25%          50%          75%  \
# parcelid                      1.1549e+07  1.25406e+07  1.42193e+07
# logerror                         -0.0253        0.006       0.0392
# transactiondate                      NaN          NaN          NaN
# airconditioningtypeid                NaN          NaN          NaN
# architecturalstyletypeid             NaN          NaN          NaN
# basementsqft                         280          588          819
# bathroomcnt                            2            2            3
# bedroomcnt                             2            3            4
# buildingclasstypeid                  NaN          NaN          NaN
# buildingqualitytypeid                  4            7            7
# calculatedbathnbr                      2            2            3
# decktypeid                           NaN          NaN          NaN
# finishedfloor1squarefeet             945         1252         1615
# calculatedfinishedsquarefeet        1183         1541         2103
# finishedsquarefeet12                1172         1520         2065
# finishedsquarefeet13                1344         1440         1440
# finishedsquarefeet15                1634         2099         2845
# finishedsquarefeet50                 945         1252         1619
# finishedsquarefeet6                 1057         1886         3240
# fips                                 NaN          NaN          NaN
# fireplacecnt                           1            1            1
# fullbathcnt                            2            2            3
# garagecarcnt                           2            2            2
# garagetotalsqft                        0          434          488
# hashottuborspa                       NaN          NaN          NaN
# heatingorsystemtypeid                NaN          NaN          NaN
# latitude                         33.8129      34.0217      34.1734
# longitude                       -118.413     -118.177     -117.925
# lotsizesquarefeet                   5702         7200      11746.8
# poolcnt                                1            1            1
# ...                                  ...          ...          ...
# pooltypeid2                          NaN          NaN          NaN
# pooltypeid7                          NaN          NaN          NaN
# propertycountylandusecode            NaN          NaN          NaN
# propertylandusetypeid                NaN          NaN          NaN
# propertyzoningdesc                   NaN          NaN          NaN
# rawcensustractandblock               NaN          NaN          NaN
# regionidcity                         NaN          NaN          NaN
# regionidcounty                       NaN          NaN          NaN
# regionidneighborhood                 NaN          NaN          NaN
# regionidzip                        96193        96389        96987
# roomcnt                                0            0            0
# storytypeid                          NaN          NaN          NaN
# threequarterbathnbr                    1            1            1
# typeconstructiontypeid               NaN          NaN          NaN
# unitcnt                                1            1            1
# yardbuildingsqft17                   175          252          375
# yardbuildingsqft26                    88          160          320
# yearbuilt                           1953         1970         1987
# numberofstories                        1            1            2
# fireplaceflag                        NaN          NaN          NaN
# structuretaxvaluedollarcnt         82568       134051       214257
# taxvaluedollarcnt                 202652       350000       554002
# assessmentyear                      2015         2015         2016
# landtaxvaluedollarcnt              83730       197776       355334
# taxamount                        2798.07      4501.04      6914.16
# taxdelinquencyflag                   NaN          NaN          NaN
# taxdelinquencyyear                  2013         2014         2015
# censustractandblock                  NaN          NaN          NaN
# transaction_year                    2016         2016         2017
# transaction_month                      3            6            8
#
#                                       max missing_ratio           dtype
# parcelid                      1.67689e+08             0           int64
# logerror                            5.263             0         float64
# transactiondate                       NaN             0  datetime64[ns]
# airconditioningtypeid                 NaN       0.67962          object
# architecturalstyletypeid              NaN      0.997212          object
# basementsqft                         3560      0.999446         float64
# bathroomcnt                            20   0.000202516         float64
# bedroomcnt                             16   0.000202516         float64
# buildingclasstypeid                   NaN      0.999815          object
# buildingqualitytypeid                  12       0.36164         float64
# calculatedbathnbr                      20      0.010912         float64
# decktypeid                            NaN      0.992424          object
# finishedfloor1squarefeet             7625      0.923205         float64
# calculatedfinishedsquarefeet        35640    0.00533689         float64
# finishedsquarefeet12                21929     0.0498487         float64
# finishedsquarefeet13                 1584      0.999553         float64
# finishedsquarefeet15                35640      0.960742         float64
# finishedsquarefeet50                12467      0.923205         float64
# finishedsquarefeet6                  7224      0.995193         float64
# fips                                  NaN   0.000202516          object
# fireplacecnt                            5      0.893405         float64
# fullbathcnt                            20      0.010912         float64
# garagecarcnt                           24      0.669679         float64
# garagetotalsqft                      7339      0.669679         float64
# hashottuborspa                        NaN             0            bool
# heatingorsystemtypeid                 NaN      0.370705          object
# latitude                          34.8188   0.000202516         float64
# longitude                        -117.555   0.000202516         float64
# lotsizesquarefeet             6.97101e+06      0.109847         float64
# poolcnt                                 1      0.797037         float64
# ...                                   ...           ...             ...
# pooltypeid2                           NaN             0            bool
# pooltypeid7                           NaN             0            bool
# propertycountylandusecode             NaN   0.000208472          object
# propertylandusetypeid                 NaN   0.000202516          object
# propertyzoningdesc                    NaN      0.352014          object
# rawcensustractandblock                NaN   0.000202516          object
# regionidcity                          NaN     0.0197096          object
# regionidcounty                        NaN   0.000202516          object
# regionidneighborhood                  NaN      0.601008          object
# regionidzip                        399675   0.000708806         float64
# roomcnt                                18   0.000202516         float64
# storytypeid                           NaN      0.999446          object
# threequarterbathnbr                     7      0.868275         float64
# typeconstructiontypeid                NaN      0.996891          object
# unitcnt                               237      0.350424         float64
# yardbuildingsqft17                   3191      0.969986         float64
# yardbuildingsqft26                   1366      0.999017         float64
# yearbuilt                            2016    0.00631373         float64
# numberofstories                         6      0.772652         float64
# fireplaceflag                         NaN             0            bool
# structuretaxvaluedollarcnt    1.14218e+07    0.00315091         float64
# taxvaluedollarcnt             4.90612e+07   0.000214429         float64
# assessmentyear                       2016   0.000202516         float64
# landtaxvaluedollarcnt         4.89522e+07   0.000220385         float64
# taxamount                          586639   0.000268036         float64
# taxdelinquencyflag                    NaN             0            bool
# taxdelinquencyyear                   2015      0.972106         float64
# censustractandblock                   NaN    0.00527733          object
# transaction_year                     2017             0           int64
# transaction_month                      12             0           int64
#
# [62 rows x 15 columns]

# %% [markdown]
# ## 2.2 Exploring Target Variable: logerror

# %%
# cencus와 rawcensus의 앞 네자리로 변수를 만들고 다른 변수들과 묶기
merged["census_1"] = merged["censustractandblock"].astype("str").apply(lambda x: x[:4])
merged["census_1"][merged["census_1"] == 'nan'] = np.nan
merged["raw_census_1"] = merged["rawcensustractandblock"].astype("str").apply(lambda x: x[:4])
merged["raw_census_1"][merged["raw_census_1"] == 'nan'] = np.nan
county_df = merged[["fips", "regionidcounty", "census_1", "raw_census_1","logerror"]].tail()
county_df.tail()
# Out:
#           fips regionidcounty census_1 raw_census_1  logerror
# 167883  6037.0         3101.0     6037         6037 -0.002245
# 167884  6037.0         3101.0     6037         6037  0.020615
# 167885  6111.0         2061.0     6111         6111  0.013209
# 167886  6037.0         3101.0     6037         6037  0.037129
# 167887  6037.0         3101.0     6037         6037  0.007204

# %%
# censustractandblock & rawcensustractandblock의 5-10자리 부분: census tract → class가 3000개 이상이라 너무 많은 것으로 생각됨
merged["census_2"] = merged["censustractandblock"].astype("str").apply(lambda x: x[4:10])
merged["census_2"][merged["census_2"] == ""] = np.nan
census_2 = pd.DataFrame(merged["census_2"])
census_2 = census_2.groupby("census_2").size().reset_index(name='counts')

merged["raw_census_2"] = merged["rawcensustractandblock"].astype("str").apply(lambda x: x[4:11])
merged["raw_census_2"][merged["raw_census_2"] == ""] = np.nan
raw_census_2 = pd.DataFrame(merged["raw_census_2"])
raw_census_2 = raw_census_2.groupby("raw_census_2").size().reset_index(name='counts')

# %%
# censustractandblock & rawcensustractandblock의 5-10자리 부분 중 첫째 자리로 카테고리화 (카테고리 수를 줄임)
merged["census_3"] = merged["censustractandblock"].astype("str").apply(lambda x: x[4:5])
merged["census_3"][merged["census_3"] == ''] = np.nan
census_3 = pd.DataFrame(merged["census_3"])
census_3 = census_3.groupby("census_3").size().reset_index(name='counts')

merged["raw_census_3"] = merged["rawcensustractandblock"].astype("str").apply(lambda x: x[4:5])
merged["raw_census_3"][merged["raw_census_3"] == ''] = np.nan
raw_census_3 = pd.DataFrame(merged["raw_census_3"])
raw_census_3 = raw_census_3.groupby("raw_census_3").size().reset_index(name='counts')

# %%
# censustractandblock & rawcensustractandblock의 1-5자리로 카테고리화
merged["census_4"] = merged["censustractandblock"].astype("str").apply(lambda x: x[:5])
merged["census_4"][merged["census_4"] == 'nan'] = np.nan
census_4 = pd.DataFrame(merged["census_4"])
census_4 = census_4.groupby("census_4").size().reset_index(name='counts')

merged["raw_census_4"] = merged["rawcensustractandblock"].astype("str").apply(lambda x: x[:5])
merged["raw_census_4"][merged["raw_census_4"] == 'nan'] = np.nan
raw_census_4 = pd.DataFrame(merged["raw_census_4"])
raw_census_4 = raw_census_4.groupby("raw_census_4").size().reset_index(name='counts')

# %%
### 입력오류라고 보고 NaN값 처리
merged["regionidzip"][merged["regionidzip"]>=100000] = np.nan

# %%
# 첫글자로 새로운 변수 만들기 (첫 글자로 카테고리화)
merged["propertyzoningdesc_1"] = merged["propertyzoningdesc"].astype("str").apply(lambda x: x[:1])
merged["propertyzoningdesc_1"][merged["propertyzoningdesc_1"] == "n"] = np.nan

# %%
# 세번째 글자로 새로운 변수 만들기
merged["propertyzoningdesc_3"] = merged["propertyzoningdesc"].astype("str").apply(
    lambda x: x.replace("&", "").replace("-", "").replace(" ", ""))
merged["propertyzoningdesc_3"] = merged["propertyzoningdesc_3"].apply(lambda x: x[2:3])
merged["propertyzoningdesc_3"][merged["propertyzoningdesc_3"] == "n"] = np.nan
merged["propertyzoningdesc_3"][merged["propertyzoningdesc_3"] == ""] = np.nan

# %%
merged["taxdelinquencyyear_past"] = merged["transaction_year"] - merged["taxdelinquencyyear"]

# %% [markdown]
# ## **3. Feature Engineering**

# %% [markdown]
# ### 3.1 Missing Values

# %% [markdown]
# #### 3.1.1 Status of missing values
# - 데이터에 missing value가 상당히 많음, missing value의 비중을 높은 순으로 살펴보자

# %%
merged_missing = pd.DataFrame(merged_des["missing_ratio"].sort_values(ascending=False))
merged_missing.reset_index()
# Out:
#                            index missing_ratio
# 0            buildingclasstypeid      0.999815
# 1           finishedsquarefeet13      0.999553
# 2                    storytypeid      0.999446
# 3                   basementsqft      0.999446
# 4             yardbuildingsqft26      0.999017
# 5       architecturalstyletypeid      0.997212
# 6         typeconstructiontypeid      0.996891
# 7            finishedsquarefeet6      0.995193
# 8                     decktypeid      0.992424
# 9                    poolsizesum      0.989052
# 10            taxdelinquencyyear      0.972106
# 11            yardbuildingsqft17      0.969986
# 12          finishedsquarefeet15      0.960742
# 13          finishedsquarefeet50      0.923205
# 14      finishedfloor1squarefeet      0.923205
# 15                  fireplacecnt      0.893405
# 16           threequarterbathnbr      0.868275
# 17                       poolcnt      0.797037
# 18               numberofstories      0.772652
# 19         airconditioningtypeid       0.67962
# 20                  garagecarcnt      0.669679
# 21               garagetotalsqft      0.669679
# 22          regionidneighborhood      0.601008
# 23         heatingorsystemtypeid      0.370705
# 24         buildingqualitytypeid       0.36164
# 25            propertyzoningdesc      0.352014
# 26                       unitcnt      0.350424
# 27             lotsizesquarefeet      0.109847
# 28          finishedsquarefeet12     0.0498487
# 29                  regionidcity     0.0197096
# ..                           ...           ...
# 32                     yearbuilt    0.00631373
# 33  calculatedfinishedsquarefeet    0.00533689
# 34           censustractandblock    0.00527733
# 35    structuretaxvaluedollarcnt    0.00315091
# 36                   regionidzip   0.000708806
# 37                     taxamount   0.000268036
# 38         landtaxvaluedollarcnt   0.000220385
# 39             taxvaluedollarcnt   0.000214429
# 40     propertycountylandusecode   0.000208472
# 41                assessmentyear   0.000202516
# 42         propertylandusetypeid   0.000202516
# 43                          fips   0.000202516
# 44        rawcensustractandblock   0.000202516
# 45                    bedroomcnt   0.000202516
# 46                      latitude   0.000202516
# 47                     longitude   0.000202516
# 48                       roomcnt   0.000202516
# 49                   bathroomcnt   0.000202516
# 50                regionidcounty   0.000202516
# 51                      logerror             0
# 52               transactiondate             0
# 53             transaction_month             0
# 54                hashottuborspa             0
# 55              transaction_year             0
# 56                  pooltypeid10             0
# 57                   pooltypeid2             0
# 58                   pooltypeid7             0
# 59                 fireplaceflag             0
# 60            taxdelinquencyflag             0
# 61                      parcelid             0
#
# [62 rows x 2 columns]

# %% [markdown]
# #### 3.1.3 Missing Values processing

# %% [markdown]
# #### 일부 변수 추가 후 categorical / numerical 새로 분류
# - poolcnt는 dummy variable로 재분류함 (True/False)

# %%
merged_1 = merged.copy()
merged_1.tail()
# Out:
#         parcelid  logerror transactiondate airconditioningtypeid  \
# 167883  10833991 -0.002245      2017-09-20                   1.0
# 167884  11000655  0.020615      2017-09-20                   NaN
# 167885  17239384  0.013209      2017-09-21                   NaN
# 167886  12773139  0.037129      2017-09-21                   1.0
# 167887  12826780  0.007204      2017-09-25                   NaN
#
#        architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 167883                      NaN           NaN          3.0         3.0
# 167884                      NaN           NaN          2.0         2.0
# 167885                      NaN           NaN          2.0         4.0
# 167886                      NaN           NaN          1.0         3.0
# 167887                      NaN           NaN          2.0         3.0
#
#        buildingclasstypeid  buildingqualitytypeid           ...            \
# 167883                 NaN                    8.0           ...
# 167884                 NaN                    6.0           ...
# 167885                 NaN                    NaN           ...
# 167886                 NaN                    4.0           ...
# 167887                 NaN                    6.0           ...
#
#         raw_census_1 census_2  raw_census_2  census_3  raw_census_3  census_4  \
# 167883          6037   131900       1319.00         1             1     60371
# 167884          6037   101400       1014.00         1             1     60371
# 167885          6111   008402       0084.02         0             0     61110
# 167886          6037   433802       4338.02         4             4     60374
# 167887          6037   503402       5034.02         5             5     60375
#
#         raw_census_4  propertyzoningdesc_1  propertyzoningdesc_3  \
# 167883         60371                     L                     R
# 167884         60371                     L                     R
# 167885         61110                   NaN                   NaN
# 167886         60374                     S                     R
# 167887         60375                     W                     R
#
#        taxdelinquencyyear_past
# 167883                     NaN
# 167884                     NaN
# 167885                     NaN
# 167886                     NaN
# 167887                     NaN
#
# [5 rows x 73 columns]

# %%
vars = merged_des.reset_index()["index"].tolist()
vars.append("taxdelinquencyyear_past")

cat_vars = ['transactiondate',"transaction_year", "transaction_month", 'fips',
            'rawcensustractandblock', 'censustractandblock', "raw_census_1", "census_1",
            "raw_census_2", "census_2", "raw_census_3", "census_3", "raw_census_4", "census_4",
            'regionidcounty', 'regionidcity', 'regionidzip', 'regionidneighborhood', 'architecturalstyletypeid',
            'decktypeid', 'buildingclasstypeid', 'storytypeid', 'typeconstructiontypeid', 
            'propertycountylandusecode', 'propertylandusetypeid', 'propertyzoningdesc', "propertyzoningdesc_1", "propertyzoningdesc_3",            
            'taxdelinquencyflag', 'taxdelinquencyyear', 'assessmentyear',
            'heatingorsystemtypeid', 'airconditioningtypeid', 'hashottuborspa', 'fireplaceflag',
            'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'poolcnt']

num_vars = [i for i in vars if i not in cat_vars]

num_vars.remove('parcelid')
num_vars.remove('logerror')

print("number of categorical variables:", len(cat_vars))
print("number of numerical variables:", len(num_vars))
# Out:
# number of categorical variables: 39
# number of numerical variables: 32

# %% [markdown]
# #### (1) numerical variables:

# %% [markdown]
# ##### 집 면적에 관련된 실수 변수
# - imputation을 어떻게 할 거라는 설명!

# %%
def num_imputation(df):
    for var in num_vars:
        if var in ["garagecarcnt", "numberofstories"]:
            df[var] = df[var].fillna(1)
        elif var in ["buildingqualitytypeid", "roomcnt", "bedroomcnt", "unitcnt", 'bathroomcnt', 
                     'calculatedbathnbr', 'fullbathcnt', 'threequarterbathnbr', 'yearbuilt']:
            a = df[var].mode()
            df[var] = df[var].fillna(int(a[0]))
        elif var in ['finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
                     'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
                     'finishedsquarefeet50', 'finishedsquarefeet6', 'garagetotalsqft', 'lotsizesquarefeet',
                     'taxvaluedollarcnt', 'landtaxvaluedollarcnt', 'structuretaxvaluedollarcnt', 'taxamount',
                     'latitude', 'longitude']:
            df[var] = df[var].fillna(df[var].mean())
        else:    # ['poolsizesum', 'fireplacecnt', 'yardbuildingsqft17', 'yardbuildingsqft26', "poolsizesum","taxdelinquencyyear_past"]
            df[var] = df[var].fillna(0)

# %%
num_imputation(merged_1)

# %% [markdown]
# #### (2) dummy/categorical variables:

# %%
def cat_imputation(df):
    for var in cat_vars:                  
        if var in ['taxdelinquencyyear', 'assessmentyear']:
            df[var] = df[var].fillna(0)
        elif var == "poolcnt":
            df[var] = df[var].replace(1, True)
            df[var] = df[var].fillna(False)            
        elif var == "decktypeid":
            df[var] = df[var].replace('66.0', True)
            df[var] = df[var].fillna(False)         
        else:
            a = df[var].mode()
            df[var] = df[var].fillna(a[0])

# %%
cat_imputation(merged_1)

# %% [markdown]
# #### (3) imputation 후 missing value ratio 다시 체크

# %%
merged_1_des = merged_1.describe(include='all').transpose()
merged_1_des["missing_ratio"] = 1-(merged_1_des["count"]/merged_1.shape[0])
merged_1_des["dtype"] = merged_1.dtypes
merged_1_missing = pd.DataFrame(merged_1_des["missing_ratio"].sort_values(ascending=False))
merged_1_missing.reset_index()
# Out:
#                          index missing_ratio
# 0      taxdelinquencyyear_past             0
# 1        propertylandusetypeid             0
# 2                         fips             0
# 3                 fireplacecnt             0
# 4                  fullbathcnt             0
# 5                 garagecarcnt             0
# 6              garagetotalsqft             0
# 7               hashottuborspa             0
# 8        heatingorsystemtypeid             0
# 9                     latitude             0
# 10                   longitude             0
# 11           lotsizesquarefeet             0
# 12                     poolcnt             0
# 13                 poolsizesum             0
# 14                pooltypeid10             0
# 15                 pooltypeid2             0
# 16                 pooltypeid7             0
# 17         finishedsquarefeet6             0
# 18        finishedsquarefeet50             0
# 19        finishedsquarefeet15             0
# 20                  bedroomcnt             0
# 21                    logerror             0
# 22             transactiondate             0
# 23       airconditioningtypeid             0
# 24    architecturalstyletypeid             0
# 25                basementsqft             0
# 26                 bathroomcnt             0
# 27         buildingclasstypeid             0
# 28        finishedsquarefeet13             0
# 29       buildingqualitytypeid             0
# ..                         ...           ...
# 43            transaction_year             0
# 44           transaction_month             0
# 45                    census_1             0
# 46                raw_census_1             0
# 47                    census_2             0
# 48                raw_census_2             0
# 49                    census_3             0
# 50                raw_census_3             0
# 51                    census_4             0
# 52                raw_census_4             0
# 53        propertyzoningdesc_1             0
# 54       landtaxvaluedollarcnt             0
# 55              assessmentyear             0
# 56           taxvaluedollarcnt             0
# 57         threequarterbathnbr             0
# 58                regionidcity             0
# 59              regionidcounty             0
# 60        regionidneighborhood             0
# 61                 regionidzip             0
# 62                     roomcnt             0
# 63                 storytypeid             0
# 64      typeconstructiontypeid             0
# 65  structuretaxvaluedollarcnt             0
# 66                     unitcnt             0
# 67          yardbuildingsqft17             0
# 68          yardbuildingsqft26             0
# 69                   yearbuilt             0
# 70             numberofstories             0
# 71               fireplaceflag             0
# 72                    parcelid             0
#
# [73 rows x 2 columns]

# %% [markdown]
# ### 3.2 Feature Correlation

# %% [markdown]
# #### 3.2.1 Numerical Features

# %%
num_df = merged_1[num_vars]
num_df["logerror"] = merged_1["logerror"]

# %%
plt.figure(figsize=(16, 16))
cmap = sns.light_palette("purple", as_cmap=True)
sns.heatmap(num_df.corr(), annot=True, fmt='3.2f', cmap=cmap)
plt.show()

# %% [markdown]
# #### 3.2.2 Categorical Features

# %%
cat_df = merged_1[cat_vars]
cat_df["logerror"] = merged_1["logerror"]

# %% [markdown]
# ### 3.3 Determination of outliers and variables using OLS model

# %% [markdown]
# #### 3.3.1 Numerical Feature만 이용한 모델

# %%
# 전체 numerical features
model_n = sm.OLS.from_formula("logerror ~ basementsqft + bathroomcnt + bedroomcnt + calculatedbathnbr +\
finishedfloor1squarefeet + calculatedfinishedsquarefeet + finishedsquarefeet12 + finishedsquarefeet13 +\
finishedsquarefeet15 + finishedsquarefeet50 + finishedsquarefeet6 + fireplacecnt + fullbathcnt + garagecarcnt + garagetotalsqft +\
buildingqualitytypeid + latitude + longitude + lotsizesquarefeet + poolsizesum + roomcnt + threequarterbathnbr +\
unitcnt + yardbuildingsqft17 + yardbuildingsqft26 + yearbuilt + numberofstories + structuretaxvaluedollarcnt + taxvaluedollarcnt +\
landtaxvaluedollarcnt + taxamount + taxdelinquencyyear_past", data=merged_1, missing='drop')
print(model_n.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               logerror   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     26.43
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):          1.23e-156
# Time:                        13:39:08   Log-Likelihood:                 63985.
# No. Observations:              167888   AIC:                        -1.279e+05
# Df Residuals:                  167855   BIC:                        -1.276e+05
# Df Model:                          32
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0463      0.285      0.162      0.871      -0.513       0.605
# basementsqft                  5.324e-05    1.9e-05      2.797      0.005    1.59e-05    9.05e-05
# bathroomcnt                     -0.0123      0.002     -5.197      0.000      -0.017      -0.008
# bedroomcnt                       0.0016      0.001      2.904      0.004       0.001       0.003
# calculatedbathnbr                0.0106      0.004      2.681      0.007       0.003       0.018
# finishedfloor1squarefeet      1.083e-05   9.07e-06      1.195      0.232   -6.94e-06    2.86e-05
# calculatedfinishedsquarefeet -7.004e-06   4.02e-06     -1.742      0.082   -1.49e-05    8.77e-07
# finishedsquarefeet12           1.96e-05   3.92e-06      4.994      0.000    1.19e-05    2.73e-05
# finishedsquarefeet13         -4.611e-05      0.000     -0.279      0.780      -0.000       0.000
# finishedsquarefeet15           6.46e-06   4.15e-06      1.555      0.120   -1.68e-06    1.46e-05
# finishedsquarefeet50         -1.577e-05    8.5e-06     -1.856      0.063   -3.24e-05    8.86e-07
# finishedsquarefeet6            1.57e-05   5.88e-06      2.672      0.008    4.18e-06    2.72e-05
# fireplacecnt                    -0.0024      0.001     -1.660      0.097      -0.005       0.000
# fullbathcnt                      0.0005      0.003      0.166      0.868      -0.005       0.006
# garagecarcnt                     0.0006      0.001      0.428      0.669      -0.002       0.003
# garagetotalsqft              -3.513e-06   3.42e-06     -1.028      0.304   -1.02e-05    3.18e-06
# buildingqualitytypeid           -0.0009      0.000     -3.357      0.001      -0.001      -0.000
# latitude                        -0.0017      0.002     -0.791      0.429      -0.006       0.003
# longitude                      1.22e-05      0.002      0.008      0.994      -0.003       0.003
# lotsizesquarefeet             1.582e-08   3.57e-09      4.429      0.000    8.82e-09    2.28e-08
# poolsizesum                  -2.538e-05   8.34e-06     -3.044      0.002   -4.17e-05   -9.04e-06
# roomcnt                          0.0005      0.000      1.829      0.067   -3.24e-05       0.001
# threequarterbathnbr              0.0154      0.011      1.467      0.142      -0.005       0.036
# unitcnt                         -0.0002      0.001     -0.332      0.740      -0.001       0.001
# yardbuildingsqft17            -5.83e-06   7.21e-06     -0.809      0.418      -2e-05    8.29e-06
# yardbuildingsqft26           -2.607e-05   3.26e-05     -0.800      0.423   -8.99e-05    3.78e-05
# yearbuilt                     1.155e-05    2.2e-05      0.525      0.600   -3.16e-05    5.47e-05
# numberofstories                 -0.0023      0.002     -1.309      0.190      -0.006       0.001
# structuretaxvaluedollarcnt   -3.115e-07   4.38e-08     -7.106      0.000   -3.97e-07   -2.26e-07
# taxvaluedollarcnt             3.363e-07   4.36e-08      7.722      0.000    2.51e-07    4.22e-07
# landtaxvaluedollarcnt        -3.067e-07   4.36e-08     -7.033      0.000   -3.92e-07   -2.21e-07
# taxamount                    -3.195e-06   2.37e-07    -13.488      0.000   -3.66e-06   -2.73e-06
# taxdelinquencyyear_past          0.0079      0.001     10.558      0.000       0.006       0.009
# ==============================================================================
# Omnibus:                   142325.082   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        104409679.643
# Skew:                           2.951   Prob(JB):                         0.00
# Kurtosis:                     125.028   Cond. No.                     6.77e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.77e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
num_df = merged_1[num_vars]
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(num_df.values, i) for i in range(num_df.shape[1])]
vif["features"] = num_df.columns
vif.sort_values(by="VIF Factor", ascending=False)
# Out:
#        VIF Factor                      features
# 17  150129.783182                     longitude
# 8   112443.292816          finishedsquarefeet13
# 16   32635.804129                      latitude
# 25   11161.782039                     yearbuilt
# 28    6832.819177             taxvaluedollarcnt
# 29    3292.795658         landtaxvaluedollarcnt
# 11    1023.671856           finishedsquarefeet6
# 27     965.957981    structuretaxvaluedollarcnt
# 5      945.725129      finishedfloor1squarefeet
# 10     846.407942          finishedsquarefeet50
# 21     682.299861           threequarterbathnbr
# 4      607.472672             calculatedbathnbr
# 9      599.145447          finishedsquarefeet15
# 6      401.136486  calculatedfinishedsquarefeet
# 7      366.301846          finishedsquarefeet12
# 13     334.024590                   fullbathcnt
# 1      215.840631                   bathroomcnt
# 30      30.299983                     taxamount
# 26      25.025284               numberofstories
# 2       19.854131                    bedroomcnt
# 14      19.324002                  garagecarcnt
# 3       18.996150         buildingqualitytypeid
# 15      10.316900               garagetotalsqft
# 20       3.789929                       roomcnt
# 22       3.443727                       unitcnt
# 12       2.214498                  fireplacecnt
# 23       1.376725            yardbuildingsqft17
# 19       1.366583                   poolsizesum
# 18       1.112838             lotsizesquarefeet
# 31       1.028988       taxdelinquencyyear_past
# 24       1.019614            yardbuildingsqft26
# 0        1.011838                  basementsqft

# %% [markdown]
# ##### 전체 numerical features에서 VIF 높은 변수, coef.의 p-value가 높은 변수 제거한 후 scaling
# - 전체 numerical features가 들어갔을 때 adf. R2 0.005에서 0.004로 소폭 감소
# - 조건수는 6.77e+08에서 29.3으로 대폭 개선

# %%
model_n1 = sm.OLS.from_formula("logerror ~ scale(latitude) + scale(basementsqft) + scale(bathroomcnt) + scale(finishedsquarefeet12) +\
scale(fireplacecnt) + buildingqualitytypeid + scale(lotsizesquarefeet) + scale(poolsizesum) + roomcnt +\
scale(taxamount) + taxdelinquencyyear_past", data=merged_1, missing='drop')

print(model_n1.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               logerror   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     59.37
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):          1.14e-132
# Time:                        13:44:01   Log-Likelihood:                 63889.
# No. Observations:              167888   AIC:                        -1.278e+05
# Df Residuals:                  167876   BIC:                        -1.276e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0173      0.002     10.055      0.000       0.014       0.021
# scale(latitude)                -0.0011      0.000     -2.575      0.010      -0.002      -0.000
# scale(basementsqft)             0.0011      0.000      2.635      0.008       0.000       0.002
# scale(bathroomcnt)             -0.0009      0.001     -1.569      0.117      -0.002       0.000
# scale(finishedsquarefeet12)     0.0122      0.001     18.054      0.000       0.011       0.014
# scale(fireplacecnt)            -0.0011      0.001     -2.030      0.042      -0.002    -3.8e-05
# buildingqualitytypeid          -0.0008      0.000     -2.835      0.005      -0.001      -0.000
# scale(lotsizesquarefeet)        0.0018      0.000      4.426      0.000       0.001       0.003
# scale(poolsizesum)             -0.0018      0.000     -4.060      0.000      -0.003      -0.001
# roomcnt                         0.0005      0.000      2.694      0.007       0.000       0.001
# scale(taxamount)               -0.0069      0.001    -13.543      0.000      -0.008      -0.006
# taxdelinquencyyear_past         0.0077      0.001     10.364      0.000       0.006       0.009
# ==============================================================================
# Omnibus:                   142132.406   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        104113741.685
# Skew:                           2.944   Prob(JB):                         0.00
# Kurtosis:                     124.855   Cond. No.                         29.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 3.3.2 Categorical Feature만 이용한 모델

# %%
model_c = sm.OLS.from_formula("logerror ~ C(transaction_year)+0 + C(transaction_month) + C(raw_census_4) + C(fips) + C(regionidcity) +\
                              C(regionidzip) + C(architecturalstyletypeid)+ C(decktypeid) + C(buildingclasstypeid) + C(storytypeid) +\
                              C(typeconstructiontypeid) + C(propertycountylandusecode) + C(propertylandusetypeid) +\
                              C(propertyzoningdesc_3) + C(taxdelinquencyflag) +\
                              C(taxdelinquencyyear) + C(heatingorsystemtypeid) +C(airconditioningtypeid) + C(hashottuborspa) +\
                              C(fireplaceflag) + C(pooltypeid10) + C(pooltypeid2) + C(pooltypeid7) + C(poolcnt)",
                              data=merged_1, missing='drop')

print(model_c.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               logerror   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     3.907
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):          2.58e-250
# Time:                        13:57:08   Log-Likelihood:                 65016.
# No. Observations:              167888   AIC:                        -1.285e+05
# Df Residuals:                  167140   BIC:                        -1.210e+05
# Df Model:                         747
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# C(transaction_year)[2016]              1.86e+09   2.39e+09      0.777      0.437   -2.83e+09    6.55e+09
# C(transaction_year)[2017]              1.86e+09   2.39e+09      0.777      0.437   -2.83e+09    6.55e+09
# C(transaction_month)[T.2]               -0.0004      0.002     -0.170      0.865      -0.004       0.004
# C(transaction_month)[T.3]               -0.0063      0.002     -3.305      0.001      -0.010      -0.003
# C(transaction_month)[T.4]               -0.0096      0.002     -5.114      0.000      -0.013      -0.006
# C(transaction_month)[T.5]               -0.0103      0.002     -5.473      0.000      -0.014      -0.007
# C(transaction_month)[T.6]               -0.0084      0.002     -4.656      0.000      -0.012      -0.005
# C(transaction_month)[T.7]               -0.0042      0.002     -2.158      0.031      -0.008      -0.000
# C(heatingorsystemtypeid)[T.2.0]         -0.0232      0.033     -0.710      0.478      -0.087       0.041
# C(heatingorsystemtypeid)[T.20.0]        -0.0385      0.035     -1.110      0.267      -0.107       0.030
# C(heatingorsystemtypeid)[T.24.0]        -0.0326      0.033     -0.990      0.322      -0.097       0.032
# C(heatingorsystemtypeid)[T.6.0]         -0.0272      0.033     -0.827      0.408      -0.092       0.037
# C(heatingorsystemtypeid)[T.7.0]         -0.0277      0.033     -0.850      0.395      -0.092       0.036
# C(airconditioningtypeid)[T.11.0]         0.0126      0.017      0.725      0.468      -0.021       0.046
# C(airconditioningtypeid)[T.13.0]         0.0009      0.003      0.282      0.778      -0.005       0.007
# C(airconditioningtypeid)[T.3.0]          0.1175      0.165      0.710      0.478      -0.207       0.442
# C(airconditioningtypeid)[T.5.0]          0.0040      0.010      0.416      0.677      -0.015       0.023
# C(airconditioningtypeid)[T.9.0]         -0.0141      0.032     -0.443      0.658      -0.076       0.048
# C(hashottuborspa)[T.True]              4.14e+06   1.01e+07      0.408      0.683   -1.57e+07     2.4e+07
# C(fireplaceflag)[T.True]                 0.0036      0.010      0.363      0.716      -0.016       0.023
# C(pooltypeid10)[T.True]               -4.14e+06   1.01e+07     -0.408      0.683    -2.4e+07    1.57e+07
# C(pooltypeid2)[T.True]                -4.14e+06   1.01e+07     -0.408      0.683    -2.4e+07    1.57e+07
# C(pooltypeid7)[T.True]                  -0.1349      0.036     -3.745      0.000      -0.205      -0.064
# C(poolcnt)[T.True]                       0.1300      0.036      3.608      0.000       0.059       0.201
# ==============================================================================
# Omnibus:                   141726.602   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        104202612.814
# Skew:                           2.927   Prob(JB):                         0.00
# Kurtosis:                     124.909   Cond. No.                     2.75e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.37e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
ls = ['transaction_year', 'transaction_month', 'raw_census_4', 'fips', 'regionidcity', 'regionidzip', 'architecturalstyletypeid', 'decktypeid', 
      'buildingclasstypeid', 'storytypeid', 'typeconstructiontypeid', 'propertycountylandusecode', 'propertylandusetypeid',
      'propertyzoningdesc_3', 'taxdelinquencyflag', 'taxdelinquencyyear', 'heatingorsystemtypeid', 'airconditioningtypeid', 'hashottuborspa',       
      'fireplaceflag', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'poolcnt']

# %%
f_df = pd.DataFrame(columns=["var", "p-value"])

# %%
for var in ls:
    formula = ("logerror ~ C({})+0".format(str(var)))
    model = sm.OLS.from_formula(formula, data = merged_1)
    result = sm.stats.anova_lm(model.fit())
    f_df.loc[len(f_df)] = [var, result["PR(>F)"][0]]

# %%
f_df.sort_values(by='p-value')

# %%
model_c1 = sm.OLS.from_formula("logerror ~ C(transaction_year)+0 + + C(transaction_month) + C(raw_census_4) + C(fips) + C(regionidcity) +\
                              C(decktypeid) + C(buildingclasstypeid) + C(storytypeid) + C(propertylandusetypeid)",
                              data=merged_1, missing='drop')

print(model_c1.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               logerror   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.989
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):          5.81e-114
# Time:                        13:52:39   Log-Likelihood:                 64101.
# No. Observations:              167888   AIC:                        -1.278e+05
# Df Residuals:                  167671   BIC:                        -1.256e+05
# Df Model:                         216
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# C(propertylandusetypeid)[T.248.0]    -0.0032      0.005     -0.659      0.510      -0.013       0.006
# C(propertylandusetypeid)[T.260.0]     0.0436      0.016      2.657      0.008       0.011       0.076
# C(propertylandusetypeid)[T.261.0]    -0.0009      0.003     -0.339      0.735      -0.006       0.004
# C(propertylandusetypeid)[T.263.0]     0.0774      0.014      5.689      0.000       0.051       0.104
# C(propertylandusetypeid)[T.264.0]     0.0090      0.040      0.225      0.822      -0.070       0.088
# C(propertylandusetypeid)[T.265.0]    -0.0011      0.007     -0.152      0.879      -0.015       0.013
# C(propertylandusetypeid)[T.266.0]    -0.0027      0.003     -1.012      0.312      -0.008       0.003
# C(propertylandusetypeid)[T.267.0]     0.0289      0.022      1.311      0.190      -0.014       0.072
# C(propertylandusetypeid)[T.269.0]    -0.0080      0.004     -2.140      0.032      -0.015      -0.001
# C(propertylandusetypeid)[T.275.0]     0.0276      0.017      1.664      0.096      -0.005       0.060
# C(propertylandusetypeid)[T.31.0]     -0.0156      0.030     -0.524      0.600      -0.074       0.043
# C(propertylandusetypeid)[T.47.0]      1.2785      0.165      7.727      0.000       0.954       1.603
# ==============================================================================
# Omnibus:                   141420.422   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        103639415.490
# Skew:                           2.916   Prob(JB):                         0.00
# Kurtosis:                     124.579   Cond. No.                     2.25e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.04e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# #### 3.3.3 Numerical / Categorical Features를 조합한 Model
# - 2016/2017년 예측을 위해 year categorical feature를 interaction으로 많이 활용
# - 위에서 선택한 numerical feature와 categorical feature를 중심으로 조합한 model
# - properties data에 train data 내에 없는 카테고리 변수의 class가 있을 경우 prediction이 되지 않기 때문에 카테고리 변수의 추가는 최소화하기로 함

# %%
model_y1 = sm.OLS.from_formula("logerror ~ C(transaction_year)+0 + C(fips) + scale(yearbuilt) + C(transaction_year):scale(basementsqft) +\
scale(I(bathroomcnt**2)) + C(transaction_year):scale(I(finishedsquarefeet12**2)) + scale(fireplacecnt) + C(transaction_year):scale(buildingqualitytypeid) +\
C(transaction_year):scale(I(lotsizesquarefeet)) + C(transaction_year):scale(I(poolsizesum**2)) + C(transaction_year):scale(I(roomcnt**2)) +\
scale(taxamount) + scale(I(taxdelinquencyyear_past))", 
                               data=merged_1, missing='drop')
result = model_y1.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               logerror   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     33.04
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):          7.58e-127
# Time:                        13:57:54   Log-Likelihood:                 63893.
# No. Observations:              167888   AIC:                        -1.277e+05
# Df Residuals:                  167867   BIC:                        -1.275e+05
# Df Model:                          20
# Covariance Type:            nonrobust
# =================================================================================================================================
#                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# C(transaction_year)[2016]                                         0.0107      0.001     14.420      0.000       0.009       0.012
# C(transaction_year)[2017]                                         0.0164      0.001     21.476      0.000       0.015       0.018
# C(fips)[T.6059.0]                                                 0.0020      0.001      1.607      0.108      -0.000       0.005
# C(fips)[T.6111.0]                                                 0.0043      0.002      2.014      0.044       0.000       0.008
# scale(yearbuilt)                                                  0.0009      0.000      1.917      0.055   -2.14e-05       0.002
# C(transaction_year)[2016]:scale(basementsqft)                     0.0016      0.001      2.471      0.013       0.000       0.003
# C(transaction_year)[2017]:scale(basementsqft)                     0.0005      0.001      1.039      0.299      -0.000       0.002
# scale(I(bathroomcnt ** 2))                                        0.0021      0.001      3.442      0.001       0.001       0.003
# C(transaction_year)[2016]:scale(I(finishedsquarefeet12 ** 2))     0.0088      0.001     11.584      0.000       0.007       0.010
# C(transaction_year)[2017]:scale(I(finishedsquarefeet12 ** 2))     0.0105      0.001     13.818      0.000       0.009       0.012
# scale(fireplacecnt)                                              -0.0013      0.001     -2.183      0.029      -0.002      -0.000
# C(transaction_year)[2016]:scale(buildingqualitytypeid)           -0.0010      0.001     -1.653      0.098      -0.002       0.000
# C(transaction_year)[2017]:scale(buildingqualitytypeid)           -0.0041      0.001     -5.398      0.000      -0.006      -0.003
# C(transaction_year)[2016]:scale(I(lotsizesquarefeet))             0.0007      0.001      1.180      0.238      -0.000       0.002
# C(transaction_year)[2017]:scale(I(lotsizesquarefeet))             0.0023      0.001      3.850      0.000       0.001       0.003
# C(transaction_year)[2016]:scale(I(poolsizesum ** 2))             -0.0011      0.001     -1.966      0.049      -0.002   -3.33e-06
# C(transaction_year)[2017]:scale(I(poolsizesum ** 2))             -0.0026      0.001     -4.113      0.000      -0.004      -0.001
# C(transaction_year)[2016]:scale(I(roomcnt ** 2))                  0.0007      0.001      0.968      0.333      -0.001       0.002
# C(transaction_year)[2017]:scale(I(roomcnt ** 2))                  0.0026      0.001      3.216      0.001       0.001       0.004
# scale(taxamount)                                                 -0.0070      0.001    -13.157      0.000      -0.008      -0.006
# scale(I(taxdelinquencyyear_past))                                 0.0040      0.000      9.806      0.000       0.003       0.005
# ==============================================================================
# Omnibus:                   142021.957   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        104217097.961
# Skew:                           2.940   Prob(JB):                         0.00
# Kurtosis:                     124.916   Cond. No.                         8.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig = plt.figure(figsize = (16, 20))
sm.graphics.plot_partregress_grid(result, fig=fig)
fig.suptitle("")
plt.show()

# %% [markdown]
# ##### 잔차의 정규분포 테스트 결과는 p-value가 매우 낮음 → 정규분포를 따르지 않음

# %%
sp.stats.probplot(result.resid, plot=plt)
plt.show()

# %% [markdown]
# ### 3.4 Outlier

# %% [markdown]
# ##### 레버리지

# %%
influence = result.get_influence()
hat = influence.hat_matrix_diag

plt.figure(figsize=(10,2))
plt.stem(hat)
plt.show()

# %% [markdown]
# ##### 아웃라이어 - 표준화 잔차

# %%
plt.figure(figsize=(10,2))
plt.stem(result.resid_pearson)
plt.show()

# %%
idx_r = np.where(cooks_dw < fox_cr)[0]

# %% [markdown]
# ##### Cook's distance

# %%
influence = result.get_influence()
cooks_d2, pvals = influence.cooks_distance
fox_cr = 4 / (len(merged_1) - len(merged_1) - 1)
idx_c = np.where(cooks_dw < fox_cr)[0]

# %%
resid_outliers = idx_r.tolist()
print("Standardized Residual Outliers", len(resid_outliers), "개 \n", resid_outliers)

cooks_outliers = idx_c.tolist()
print("Cook's distance Outliers", len(cooks_outliers), "개 \n", cooks_outliers)

# %% [markdown]
# ## **4. Modeling**

# %% [markdown]
# #### 4.2.2 ANOVA F-test

# %% [markdown]
# #### 4.2.3 RMSE

# %% [markdown]
# #### 4.2.4 Normalization of residuals

# %% [markdown]
# ### 4.3 Predict Logerror
